# %%
import pandas as pd
import numpy as np

# %%
raw_data=pd.read_csv('zomato_raw_data.csv')
df=raw_data.copy()

# %%
df.sample(5)
# Out:
#                                                      url  \
# 20894  https://www.zomato.com/bangalore/durga-bikaner...
# 35141  https://www.zomato.com/bangalore/pin-me-down-b...
# 13439  https://www.zomato.com/bangalore/fish-chain-el...
# 4939   https://www.zomato.com/bangalore/sharaab-facto...
# 38402  https://www.zomato.com/bangalore/hyper-scoop-s...
#
#                                                  address  \
# 20894  38, Near ICICI Bank Signal, 4th F Cross, 8th M...
# 35141  29, Tavakere Main Road, Behind Forum Mall, Kor...
# 13439  Kitchens@, 1st Floor Skywards Sun Park, Neelad...
# 4939   3, 6th Floor, Bangalore Central Mall, Bellandu...
# 38402  76/1, Mission Road, Subbayya Circle, Shanti Na...
#
#                        name online_order book_table    rate  votes  \
# 20894  Durga Bikaner Sweets           No         No   3.7/5     15
# 35141           Pin Me Down          Yes        Yes  4.5 /5    819
# 13439            Fish Chain          Yes         No     NEW      0
# 4939        Sharaab Factory          Yes        Yes   3.9/5    392
# 38402           Hyper Scoop          Yes         No     NaN      0
#
#                                   phone         location           rest_type  \
# 20894                    +91 9916574352        Jayanagar         Quick Bites
# 35141    +91 8861568945\n+91 8178831745              BTM       Casual Dining
# 13439                      080 43334333  Electronic City  Takeaway, Delivery
# 4939   +91 9901755559\r\n+91 8951444448        Bellandur                 Bar
# 38402    +91 9902755155\n+91 9845656928     Shanti Nagar      Dessert Parlor
#
#                                               dish_liked  \
# 20894                                                NaN
# 35141  Paneer Tikka, Pasta, Chilli Chicken, Pizza, Mo...
# 13439                                                NaN
# 4939   Chicken Curry, Chicken Tikka, Cocktails, Long ...
# 38402                                                NaN
#
#                                           cuisines  \
# 20894                          Street Food, Mithai
# 35141  Continental, Mexican, Chinese, North Indian
# 13439                        Seafood, BBQ, Biryani
# 4939                         Biryani, North Indian
# 38402                          Desserts, Ice Cream
#
#       approx_cost(for two people)  \
# 20894                         100
# 35141                         800
# 13439                         250
# 4939                        1,500
# 38402                         300
#
#                                             reviews_list  \
# 20894  [('Rated 4.0', "RATED\n  Another famous spot i...
# 35141  [('Rated 3.0', "RATED\n  The food and ambience...
# 13439  [('Rated 5.0', 'RATED\n  I ordered from this p...
# 4939   [('Rated 3.0', 'RATED\n  Yet another impromptu...
# 38402                                                 []
#
#                                                menu_item     listed_in(type)  \
# 20894                                                 []            Desserts
# 35141                                                 []            Delivery
# 13439                                                 []            Delivery
# 4939   ['Hing Wali Dal Shorba', 'Bhune Tamatar aur Dh...  Drinks & nightlife
# 38402                                                 []            Delivery
#
#              listed_in(city)
# 20894              Jayanagar
# 35141  Koramangala 7th Block
# 13439        Electronic City
# 4939               Bellandur
# 38402           Lavelle Road

# %% [markdown]
# # Remove unwanted columns

# %%
columns_to_drop=['url','address','phone','dish_liked','menu_item','location','reviews_list','menu_item']
df.drop(columns=columns_to_drop,inplace=True)

# %%
df.sample(5)
# Out:
#                      name online_order book_table    rate  votes  \
# 2785        Kettle & Kegs          Yes         No   3.2/5      6
# 35763  Harry's Bar + Cafe          Yes        Yes  4.2 /5   1370
# 15293            Sri Rama           No         No   3.2/5      4
# 15049      Mamma Mexicana          Yes        Yes   2.2/5    406
# 2132      New Royal Treat          Yes         No   2.8/5    102
#
#                 rest_type                  cuisines  \
# 2785             Delivery            Tea, Beverages
# 35763  Casual Dining, Bar  Asian, American, Mexican
# 15293         Quick Bites              South Indian
# 15049       Casual Dining                   Mexican
# 2132          Quick Bites     North Indian, Chinese
#
#       approx_cost(for two people) listed_in(type)        listed_in(city)
# 2785                          200        Delivery           Basavanagudi
# 35763                       1,400        Delivery  Koramangala 7th Block
# 15293                         200        Delivery            Frazer Town
# 15049                       1,000        Delivery            Frazer Town
# 2132                          350        Dine-out      Bannerghatta Road

# %% [markdown]
# # Renaming the columns

# %%
df.rename(columns={'name':"Name",'rate':'Rating','votes':'Customer_rated',
                   'approx_cost(for two people)':'Cost_for_two','listed_in(type)':'Service_Category','listed_in(city)':'City'},inplace=True)

# %%
df.sample(5)
# Out:
#                                Name online_order book_table  Rating  \
# 49058                Abbabi Chicken           No         No  3.7 /5
# 28821                 Hotel Thazooq           No         No  3.3 /5
# 27706                     Star Bowl          Yes         No     NEW
# 46860  Dhanya Nati Style Restaurant           No         No  3.1 /5
# 43967                        Engine           No         No  3.3 /5
#
#        Customer_rated           rest_type  \
# 49058             134         Quick Bites
# 28821               6         Quick Bites
# 27706               0  Takeaway, Delivery
# 46860              37         Quick Bites
# 43967              16  Casual Dining, Bar
#
#                                                 cuisines Cost_for_two  \
# 49058                                          Fast Food          200
# 28821                     North Indian, Chinese, Biryani          350
# 27706                       North Indian, Chinese, Rolls          650
# 46860                                       South Indian          300
# 43967  Biryani, South Indian, North Indian, Chinese, ...          950
#
#       Service_Category                   City
# 49058         Delivery          Sarjapur Road
# 28821         Dine-out  Koramangala 4th Block
# 27706         Delivery  Koramangala 4th Block
# 46860         Dine-out            Rajajinagar
# 43967    Pubs and bars                MG Road

# %% [markdown]
# # Remove Duplicates

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
# Out:
# np.int64(124)

# %%
df.sample(5)
# Out:
#                              Name online_order book_table  Rating  \
# 51306  The Coffee Bean & Tea Leaf          Yes         No  3.0 /5
# 36817                    7 Plates          Yes         No  3.7 /5
# 38472            The Waffle Press          Yes         No  4.3 /5
# 43250                   Nagarjuna           No         No  4.3 /5
# 28350             Vasudev Adiga's           No         No  2.8 /5
#
#        Customer_rated       rest_type  \
# 51306              38            Cafe
# 36817             259   Casual Dining
# 38472             120  Dessert Parlor
# 43250            1792   Casual Dining
# 28350             289   Casual Dining
#
#                                                cuisines Cost_for_two  \
# 51306                                      Cafe, Coffee          700
# 36817                                Mughlai, Fast Food          750
# 38472                               Desserts, Ice Cream          400
# 43250                                   Andhra, Biryani          800
# 28350  South Indian, North Indian, Chinese, Street Food          250
#
#       Service_Category                   City
# 51306         Dine-out             Whitefield
# 36817         Dine-out  Koramangala 7th Block
# 38472         Desserts           Lavelle Road
# 43250         Dine-out                MG Road
# 28350         Dine-out  Koramangala 4th Block

# %% [markdown]
# # Split Rating Column

# %%
df['Rating_out_of_5']=df['Rating'].str.extract(r'(\d+.\d+|\d+)',expand=True)
df['Rating_out_of_5']=pd.to_numeric(df['Rating_out_of_5'],errors='coerce')

# %%
df.drop(columns=['Rating'],inplace=True)

# %%
df.sample(5)
# Out:
#                  Name online_order book_table  Customer_rated  \
# 20714   Wellness Cafe           No         No               0
# 23772   Armaani Caffe          Yes         No              12
# 33837  Cashmere Nites          Yes         No              74
# 1589       Foodiction           No         No              54
# 6119     The Open Box          Yes        Yes            2270
#
#                 rest_type                                           cuisines  \
# 20714                Cafe                                 Cafe, Healthy Food
# 23772         Quick Bites                                          Fast Food
# 33837       Casual Dining                                           Kashmiri
# 1589          Quick Bites           North Indian, Fast Food, Chinese, Burger
# 6119   Casual Dining, Bar  European, North Indian, Mediterranean, Asian, ...
#
#       Cost_for_two Service_Category                   City  Rating_out_of_5
# 20714          400         Delivery              Jayanagar              NaN
# 23772          250         Dine-out               JP Nagar              3.5
# 33837          600         Dine-out  Koramangala 6th Block              3.5
# 1589           500         Delivery      Bannerghatta Road              2.9
# 6119         1,400         Dine-out           Brigade Road              4.2
