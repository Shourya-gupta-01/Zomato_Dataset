# %%
import pandas as pd
import numpy as np

# %%
raw_data=pd.read_csv('zomato_raw_data.csv')
df=raw_data.copy()

# %%
df.sample(5)
# Out:
#                                                      url  \
# 24860  https://www.zomato.com/bangalore/yuan-restaura...
# 51498  https://www.zomato.com/bangalore/mothi-family-...
# 17110  https://www.zomato.com/bangalore/thalassery-me...
# 16500  https://www.zomato.com/bangalore/swad-e-punjab...
# 34234  https://www.zomato.com/bangalore/laziz-pizza-k...
#
#                                                  address  \
# 24860  2&3, Renu Arcade, 1st Stage, 2nd Block, 80 Fee...
# 51498  454, Whitefield Main Road, Opposite South Indi...
# 17110  31, 4th Cross Road, Mangammanapalya, HSR, Bang...
# 16500  458, Ground Floor, 2nd Main, Outer Ring Road, ...
# 34234  Shop 213, Grace Point, Opposite Bosch Back Gat...
#
#                           name online_order book_table    rate  votes  \
# 24860          Yuan Restaurant          Yes         No   3.8/5    202
# 51498  Mothi Family Restaurant           No         No     NaN      0
# 17110          Thalassery Mess           No         No   3.3/5      7
# 16500          Swad 'E' Punjab          Yes         No   3.6/5     49
# 34234              Laziz Pizza          Yes         No  3.8 /5     47
#
#                                   phone               location      rest_type  \
# 24860  +91 9901047070\r\n00 08040974045             HBR Layout  Casual Dining
# 51498                    +91 7795386903             Whitefield    Quick Bites
# 17110  +91 7829745323\r\n+91 8892743136                    HSR           Mess
# 16500    +91 9986006784\r\n080 25533115                    HSR  Casual Dining
# 34234                      080 49652743  Koramangala 7th Block    Quick Bites
#
#                                              dish_liked  \
# 24860  Momos, Spring Roll, Manchow Soup, Dragon Noodles
# 51498                                               NaN
# 17110                                               NaN
# 16500                                               NaN
# 34234               Pizza, Peri Peri Fries, Veg Paprika
#
#                              cuisines approx_cost(for two people)  \
# 24860                  Chinese, Momos                         600
# 51498      South Indian, North Indian                         350
# 17110                          Kerala                         300
# 16500  North Indian, Chinese, Mughlai                         500
# 34234        Fast Food, Burger, Pizza                         400
#
#                                             reviews_list menu_item  \
# 24860  [('Rated 4.0', "RATED\n  It's a small outlet t...        []
# 51498  [('Rated 4.0', 'RATED\n  food was great I had ...        []
# 17110  [('Rated 3.5', 'RATED\n  Visited them on Sunda...        []
# 16500  [('Rated 3.0', 'RATED\n  One of the best place...        []
# 34234  [('Rated 2.0', "RATED\n  Zomato was running an...        []
#
#       listed_in(type)        listed_in(city)
# 24860        Dine-out           Kalyan Nagar
# 51498        Dine-out             Whitefield
# 17110        Dine-out                    HSR
# 16500        Delivery                    HSR
# 34234        Dine-out  Koramangala 6th Block

# %% [markdown]
# # Remove unwanted columns

# %%
columns_to_drop=['url','address','phone','dish_liked','menu_item','location','reviews_list','menu_item']
df.drop(columns=columns_to_drop,inplace=True)

# %%
df.sample(5)
# Out:
#                                  name online_order book_table    rate  votes  \
# 40556               Risalo Restaurant           No         No     NaN      0
# 16409                  Mynutrikitchen          Yes         No   3.6/5     59
# 42382         Soda Bottle Opener Wala          Yes        Yes  4.5 /5   3709
# 9865   Midnight Hunger Solutions 24/7           No         No   3.2/5     11
# 29617                      McDonald's          Yes         No  3.8 /5    295
#
#                         rest_type                        cuisines  \
# 40556                         NaN                             NaN
# 16409                    Delivery      North Indian, Healthy Food
# 42382  Casual Dining, Irani Cafee             Parsi, North Indian
# 9865                     Delivery  North Indian, Mughlai, Chinese
# 29617                 Quick Bites               Fast Food, Burger
#
#       approx_cost(for two people) listed_in(type)        listed_in(city)
# 40556                         NaN           Cafes           Marathahalli
# 16409                         300        Delivery                    HSR
# 42382                       1,300        Delivery                MG Road
# 9865                          500        Delivery                    BTM
# 29617                         500        Delivery  Koramangala 5th Block

# %% [markdown]
# # Renaming the columns

# %%
df.rename(columns={'name':"Name",'rate':'Rating','votes':'Customer_rated',
                   'approx_cost(for two people)':'Cost_for_two','listed_in(type)':'Service_Category','listed_in(city)':'City'},inplace=True)

# %%
df.sample(5)
# Out:
#                                     Name online_order book_table  Rating  \
# 2847                     Mr. Parathewala          Yes         No     NaN
# 38769                           Desi Inn          Yes         No  3.5 /5
# 49536                 Delhi Food Factory          Yes         No     NaN
# 6243              Polo Club - The Oberoi           No         No   4.1/5
# 19409  The Maori - Aurick Boutique Hotel           No         No   3.5/5
#
#        Customer_rated           rest_type  \
# 2847                0  Takeaway, Delivery
# 38769              13         Quick Bites
# 49536               0            Delivery
# 6243              117         Fine Dining
# 19409              44       Casual Dining
#
#                                         cuisines Cost_for_two  \
# 2847                                North Indian          300
# 38769                               North Indian          300
# 49536                               North Indian          500
# 6243   American, North Indian, European, Tex-Mex        3,000
# 19409                      Chinese, North Indian        1,000
#
#       Service_Category           City
# 2847          Delivery   Basavanagudi
# 38769         Dine-out   Lavelle Road
# 49536         Delivery  Sarjapur Road
# 6243          Dine-out   Brigade Road
# 19409           Buffet      Jayanagar

# %% [markdown]
# # Remove Duplicates

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.sample(5)
# Out:
#                                             Name online_order book_table  \
# 19925                             Domino's Pizza          Yes         No
# 17631  CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Felix          Yes        Yes
# 13571                                 The Mirchi          Yes         No
# 4872                               Baba Da Dhaba           No        Yes
# 19586                                     Onesta          Yes        Yes
#
#       Rating  Customer_rated            rest_type  \
# 19925  3.7/5             386          Quick Bites
# 17631  4.4/5             688  Casual Dining, Cafe
# 13571  3.3/5              22   Takeaway, Delivery
# 4872   3.6/5              32        Casual Dining
# 19586  4.6/5            2604  Casual Dining, Cafe
#
#                              cuisines Cost_for_two Service_Category  \
# 19925                Pizza, Fast Food          400         Delivery
# 17631     American, Cafe, Continental        1,700            Cafes
# 13571  Chinese, North Indian, Bengali          400         Delivery
# 4872                     North Indian          650         Dine-out
# 19586            Pizza, Cafe, Italian          600         Delivery
#
#                   City
# 19925        Jayanagar
# 17631      Indiranagar
# 13571  Electronic City
# 4872         Bellandur
# 19586        Jayanagar

# %% [markdown]
# # Split Rating Column

# %%
df['Rating_out_of_5']=df['Rating'].str.extract(r'(\d+.\d+|\d+)',expand=True)
df['Rating_out_of_5']=pd.to_numeric(df['Rating_out_of_5'],errors='coerce')

# %%
df.drop(columns=['Rating'],inplace=True)

# %%
df.sample(5)
# Out:
#                              Name online_order book_table  Customer_rated  \
# 6076   Portland Steakhouse & Cafe          Yes        Yes            2040
# 34641                      Barkat           No         No               6
# 44926         Smally's Resto Cafe          Yes         No             424
# 4460                   Kakatiya's          Yes         No               6
# 29904             Cream Chemistry          Yes         No             231
#
#             rest_type                                           cuisines  \
# 6076    Casual Dining  Steak, Italian, Continental, American, Burger,...
# 34641     Quick Bites                                             Kerala
# 44926            Cafe             Cafe, Italian, Burger, American, Steak
# 4460      Quick Bites                              South Indian, Biryani
# 29904  Dessert Parlor                                Ice Cream, Desserts
#
#       Cost_for_two Service_Category                   City  Rating_out_of_5
# 6076         1,500         Dine-out           Brigade Road              4.3
# 34641          250         Dine-out  Koramangala 6th Block              3.4
# 44926          650         Delivery       Old Airport Road              4.1
# 4460           250         Delivery              Bellandur              3.1
# 29904          500         Delivery  Koramangala 5th Block              3.9

# %% [markdown]
# # Clean rest_type column

# %%
df['rest_type']=df['rest_type'].str.replace('Cafee','Cafe')

# %%
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Delivery', na=False), 'rest_type'] = 'Quick Bites'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Dine-out', na=False), 'rest_type'] = 'Casual Dining'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Cafes', na=False), 'rest_type'] = 'Cafe'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Desserts', na=False), 'rest_type'] = 'Dessert Parlor'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Drinks', na=False), 'rest_type'] = 'Pub,Bar'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Buffet', na=False), 'rest_type'] = 'Buffet'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Pubs and bars', na=False), 'rest_type'] = 'Pub,Bar'

# %%
df.sample(5)
# Out:
#                          Name online_order book_table  Customer_rated  \
# 38018  The Belgian Waffle Co.          Yes         No              75
# 15229         Rolls On Wheels           No         No              61
# 50759          Umami & Beyond           No         No               0
# 9868                     Owly           No         No              27
# 20062                 3 Spice          Yes         No             157
#
#             rest_type                      cuisines Cost_for_two  \
# 38018  Dessert Parlor           Desserts, Beverages          350
# 15229     Quick Bites       Fast Food, Rolls, Momos          200
# 50759        Delivery  American, Thai, Healthy Food          500
# 9868         Delivery       Fast Food, North Indian          350
# 20062   Casual Dining         North Indian, Chinese          450
#
#       Service_Category          City  Rating_out_of_5
# 38018         Delivery  Lavelle Road              3.7
# 15229         Delivery   Frazer Town              3.7
# 50759         Delivery    Whitefield              NaN
# 9868          Delivery           BTM              3.7
# 20062         Delivery     Jayanagar              3.9

# %% [markdown]
# # Fill missing values for Cost_for_two column

# %%
df['Cost_for_two']=df['Cost_for_two'].str.replace(',','')
df['Cost_for_two']=pd.to_numeric(df['Cost_for_two'],errors='coerce')

# %%
df['Cost_for_two'] = df.groupby(['City', 'rest_type'])['Cost_for_two'].transform(lambda x: x.fillna(x.median()))
df['Cost_for_two'] = df.groupby(['City', 'Service_Category'])['Cost_for_two'].transform(lambda x: x.fillna(x.median()))
# Out:
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# # fill cuisines column

# %%
df['cuisines'] = df['cuisines'].fillna(df.groupby(['City', 'rest_type'])['cuisines'].transform(lambda x: x.mode()[0] if not x.mode().empty else np.nan))

# %%
df['cuisines'] = df['cuisines'].fillna(df.groupby(['City', 'Service_Category'])['cuisines'].transform(lambda x: x.mode()[0] if not x.mode().empty else np.nan))

# %%
df.sample(5)
# Out:
#                              Name online_order book_table  Customer_rated  \
# 6325                The Bao Belly           No         No               9
# 36396                     BelgYum          Yes         No              69
# 42856                    Truffles           No         No            3595
# 46698            Apsara Ice Cream          Yes         No              25
# 14420  MKA Ambur Hot Dum Biriyani           No         No               0
#
#             rest_type                       cuisines  Cost_for_two  \
# 6325             Cafe                           Cafe         400.0
# 36396  Dessert Parlor                       Desserts         400.0
# 42856            Cafe  Cafe, American, Burger, Steak         900.0
# 46698  Dessert Parlor            Ice Cream, Desserts         200.0
# 14420     Quick Bites                        Biryani         200.0
#
#       Service_Category                   City  Rating_out_of_5
# 6325          Dine-out           Brigade Road              3.3
# 36396         Desserts  Koramangala 7th Block              4.0
# 42856         Delivery                MG Road              4.5
# 46698         Desserts            Rajajinagar              4.0
# 14420         Dine-out        Electronic City              NaN

# %% [markdown]
# # Fill rating column

# %%
df['Rating_out_of_5'] = df.groupby(['City', 'cuisines','rest_type'])['Rating_out_of_5'].transform(lambda x: x.fillna(x.median()))

# %%
df['Rating_out_of_5'] = df.groupby(['City'])['Rating_out_of_5'].transform(lambda x: x.fillna(x.median()))
