# %%
import pandas as pd
import numpy as np

# %%
raw_data=pd.read_csv('zomato_raw_data.csv')
df=raw_data.copy()

# %%
df.sample(5)
# Out:
#                                                      url  \
# 11396  https://www.zomato.com/bangalore/snack-n-slurp...
# 46106  https://www.zomato.com/bangalore/1131-bar-kitc...
# 16590  https://www.zomato.com/bangalore/t-a-k-that-af...
# 3375   https://www.zomato.com/bangalore/basavanagudi-...
# 4738   https://www.zomato.com/bangalore/punjabi-bella...
#
#                                                  address  \
# 11396  1332, 24th Main Road, Kottapalya, 9th block Ja...
# 46106  100 Feet Road, HAL 2nd Stage, Indiranagar, Ban...
# 16590                                     HSR, Bangalore
# 3375   26/2, Bugle Rock Rd, Gandhi Bazaar, Basavanagu...
# 4738             186, Sri Sai Mansion, Green Glen Layout
#
#                                   name online_order book_table    rate  votes  \
# 11396                    Snack N Slurp           No         No     NaN      0
# 46106               1131 Bar + Kitchen           No        Yes  4.4 /5   2861
# 16590  T.A.K - That Affordable Kitchen          Yes         No   3.2/5      4
# 3375               Basavanagudi Mylari           No         No  4.0 /5     53
# 4738                           Punjabi           No         No     NaN      0
#
#                                   phone      location           rest_type  \
# 11396  +91 8073773808\r\n+91 9538979798     Jayanagar         Quick Bites
# 46106                      080 49652166   Indiranagar  Bar, Casual Dining
# 16590  +91 9731523151\r\n+91 8792446647           HSR  Takeaway, Delivery
# 3375                     +91 9880623407  Basavanagudi         Quick Bites
# 4738                     +91 7829709777     Bellandur         Quick Bites
#
#                                               dish_liked  \
# 11396                                                NaN
# 46106  Pizza, Chocolate Cake, Cocktails, Nachos, Sang...
# 16590                                                NaN
# 3375   Coffee, Idli, Masala Dosa, Sagu Dosa, Kesari B...
# 4738                                                 NaN
#
#                                         cuisines approx_cost(for two people)  \
# 11396           Burger, Sandwich, Pizza, Chinese                         200
# 46106  Continental, Asian, Italian, North Indian                       1,500
# 16590                  Continental, North Indian                         400
# 3375                                South Indian                         300
# 4738                       North Indian, Chinese                         500
#
#                                             reviews_list menu_item  \
# 11396                                                 []        []
# 46106  [('Rated 2.0', 'RATED\n  We went here for team...        []
# 16590  [('Rated 3.0', 'RATED\n  I had ordered their b...        []
# 3375   [('Rated 4.0', "RATED\n  Mysuru's legendary my...        []
# 4738   [('Rated 1.0', 'RATED\n  Delivery was quick, b...        []
#
#       listed_in(type)   listed_in(city)
# 11396        Dine-out               BTM
# 46106   Pubs and bars  Old Airport Road
# 16590        Delivery               HSR
# 3375         Dine-out      Basavanagudi
# 4738         Dine-out         Bellandur

# %% [markdown]
# # Remove unwanted columns

# %%
columns_to_drop=['url','address','phone','dish_liked','menu_item','location','reviews_list','menu_item']
df.drop(columns=columns_to_drop,inplace=True)

# %%
df.sample(5)
# Out:
#                     name online_order book_table    rate  votes  \
# 33344    Nandhana Palace           No        Yes  4.1 /5    819
# 379         Sri Sai Cafe          Yes         No   3.5/5     10
# 33635          Zee5 Loft          Yes         No  4.4 /5    363
# 481        Biriyani Mane          Yes         No   3.8/5    130
# 6358   Indian Spice Food          Yes         No   3.6/5     15
#
#                 rest_type                                    cuisines  \
# 33344  Casual Dining, Bar      Andhra, Biryani, North Indian, Chinese
# 379           Quick Bites                                South Indian
# 33635                Cafe  Cafe, North Indian, Pizza, Sandwich, Salad
# 481           Quick Bites                       North Indian, Biryani
# 6358          Quick Bites                       North Indian, Chinese
#
#       approx_cost(for two people) listed_in(type)        listed_in(city)
# 33344                         800        Delivery  Koramangala 6th Block
# 379                           200        Delivery           Banashankari
# 33635                         500        Desserts  Koramangala 6th Block
# 481                           400        Delivery           Banashankari
# 6358                          300        Dine-out           Brigade Road

# %% [markdown]
# # Renaming the columns

# %%
df.rename(columns={'name':"Name",'rate':'Rating','votes':'Customer_rated',
                   'approx_cost(for two people)':'Cost_for_two','listed_in(type)':'Service_Category','listed_in(city)':'City'},inplace=True)

# %%
df.sample(5)
# Out:
#                   Name online_order book_table  Rating  Customer_rated  \
# 41513  Renees Cake Art           No         No     NaN               0
# 42658        Cafe Idly          Yes         No  3.7 /5              81
# 11800        Keventers          Yes         No   3.8/5              54
# 14647      Cafe Nibras           No         No   3.4/5              10
# 29513  New Udupi Grand          Yes         No  3.6 /5              36
#
#                            rest_type  \
# 41513                         Bakery
# 42658                    Quick Bites
# 11800  Beverage Shop, Dessert Parlor
# 14647                           Cafe
# 29513                    Quick Bites
#
#                                                cuisines Cost_for_two  \
# 41513                                  Bakery, Desserts          400
# 42658                           South Indian, Fast Food          200
# 11800                    Desserts, Beverages, Ice Cream          400
# 14647                                 Cafe, Continental          400
# 29513  South Indian, North Indian, Chinese, Street Food          250
#
#       Service_Category                   City
# 41513         Desserts           Marathahalli
# 42658         Delivery                MG Road
# 11800         Delivery          Church Street
# 14647            Cafes            Frazer Town
# 29513         Delivery  Koramangala 5th Block
