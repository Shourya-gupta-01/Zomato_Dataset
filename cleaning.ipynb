# %%
import pandas as pd
import numpy as np

# %%
raw_data=pd.read_csv('zomato_raw_data.csv')
df=raw_data.copy()

# %%
df.sample(5)
# Out:
#                                                      url  \
# 17694  https://www.zomato.com/bangalore/chakh-le-food...
# 18865  https://www.zomato.com/bangalore/dominos-pizza...
# 20120  https://www.zomato.com/bangalore/tandoor-merch...
# 11558  https://www.zomato.com/bangalore/the-market-th...
# 11277  https://www.zomato.com/bangalore/nandhanus-ras...
#
#                                                  address  \
# 17694  513, First Floor, 10th Main Road, Jeevan Bhima...
# 18865  308, 2nd Stage, 100 Feet Road, Indiranagar, Ba...
# 20120  18, 4th Cross, 4th Link Road, Maruthi Nagar, M...
# 11558    The Ritz-Carlton, 99, Residency Road, Bangalore
# 11277  #2035, 26th Main, South F Cross, Opposite Ragi...
#
#                                 name online_order book_table   rate  votes  \
# 17694                 Chakh Le Foods          Yes        Yes  3.4/5    257
# 18865                 Domino's Pizza          Yes         No  3.0/5    464
# 20120               Tandoor Merchant          Yes         No  3.4/5     22
# 11558  The Market - The Ritz-Carlton           No        Yes  4.3/5    614
# 11277                Nandhanus Rasoi          Yes         No  3.4/5      9
#
#                                 phone            location           rest_type  \
# 17694  080 41255090\r\n+91 9035043643  Jeevan Bhima Nagar       Casual Dining
# 18865     080 25217444\r\n18602100000         Indiranagar         Quick Bites
# 20120                  +91 7259015811                 BTM  Takeaway, Delivery
# 11558                    080 49148341      Residency Road         Fine Dining
# 11277                  +91 9632490428           Jayanagar         Quick Bites
#
#                                               dish_liked  \
# 17694                                   Fish, Aloo Posto
# 18865  Pane Pizza, Garlic Bread, Pepperoni Pizza, Cho...
# 20120                                                NaN
# 11558  Pizza, Waffles, Pasta, Sushi, Salads, Fish, Co...
# 11277                                                NaN
#
#                                       cuisines approx_cost(for two people)  \
# 17694  North Indian, Mughlai, Bengali, Chinese                         500
# 18865                         Pizza, Fast Food                         800
# 20120         North Indian, Chinese, Fast Food                         500
# 11558             North Indian, European, Thai                       3,400
# 11277             Chinese, Rolls, North Indian                         200
#
#                                             reviews_list  \
# 17694  [('Rated 2.0', "RATED\n  Ordered Chicken thali...
# 18865  [('Rated 4.0', 'RATED\n  I went to dominos in ...
# 20120  [('Rated 2.0', "RATED\n  The food is not good ...
# 11558  [('Rated 3.0', 'RATED\n  Went there for buffet...
# 11277  [('Rated 1.0', "RATED\n  Horrible tawa palau r...
#
#                                                menu_item listed_in(type)  \
# 17694                                                 []        Delivery
# 18865  ['Margherita', 'Farmhouse', 'Mexican Green Wav...        Dine-out
# 20120  ['Peanut Masala', 'French Fry', 'Chicken Pakod...        Delivery
# 11558                                                 []          Buffet
# 11277                                                 []        Dine-out
#
#       listed_in(city)
# 17694     Indiranagar
# 18865     Indiranagar
# 20120       Jayanagar
# 11558   Church Street
# 11277             BTM

# %% [markdown]
# # Remove unwanted columns

# %%
columns_to_drop=['url','address','phone','dish_liked','menu_item','location','reviews_list','menu_item']
df.drop(columns=columns_to_drop,inplace=True)

# %%
df.sample(5)
# Out:
#                             name online_order book_table    rate  votes  \
# 7935                Chaat Street          Yes         No   4.1/5    219
# 50234  KBC - Kebab Biryani Curry          Yes         No  3.4 /5     38
# 26247        Taste Of The Nation           No         No  3.0 /5    110
# 1126                   Keventers          Yes         No   3.8/5     29
# 38560             Brownie Heaven          Yes         No  4.2 /5     34
#
#                            rest_type                               cuisines  \
# 7935                           Kiosk              Street Food, North Indian
# 50234                    Quick Bites  North Indian, Chinese, Kebab, Biryani
# 26247                            NaN                           North Indian
# 1126   Beverage Shop, Dessert Parlor         Desserts, Beverages, Ice Cream
# 38560                 Dessert Parlor                    Desserts, Fast Food
#
#       approx_cost(for two people) listed_in(type)    listed_in(city)
# 7935                          250        Dine-out        Brookefield
# 50234                         400        Delivery         Whitefield
# 26247                         650        Dine-out       Kammanahalli
# 1126                          400        Delivery  Bannerghatta Road
# 38560                         300        Desserts       Lavelle Road

# %% [markdown]
# # Renaming the columns

# %%
df.rename(columns={'name':"Name",'rate':'Rating','votes':'Customer_rated',
                   'approx_cost(for two people)':'Cost_for_two','listed_in(type)':'Service_Category','listed_in(city)':'City'},inplace=True)

# %%
df.sample(5)
# Out:
#                      Name online_order book_table Rating  Customer_rated  \
# 381      Utsav Restaurant          Yes         No  3.8/5              61
# 23925  Imperio Restaurant          Yes        Yes  4.5/5            1228
# 11399       SS Food Point           No         No    NaN               0
# 25281           Pizza Hut          Yes         No  2.7/5             434
# 50444        Andhra Taste          Yes         No    NaN               0
#
#            rest_type                                           cuisines  \
# 381      Quick Bites                              North Indian, Chinese
# 23925  Casual Dining  North Indian, Mughlai, Biryani, South Indian, ...
# 11399    Quick Bites                              South Indian, Biryani
# 25281  Casual Dining                                   Pizza, Fast Food
# 50444       Delivery                                             Andhra
#
#       Cost_for_two Service_Category          City
# 381            300         Delivery  Banashankari
# 23925          800         Delivery  Kalyan Nagar
# 11399          250         Dine-out           BTM
# 25281          750         Delivery  Kammanahalli
# 50444          400         Delivery    Whitefield

# %% [markdown]
# # Remove Duplicates

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.sample(5)
# Out:
#                          Name online_order book_table  Rating  Customer_rated  \
# 37911           Wangs Kitchen          Yes         No  2.5 /5              22
# 26120  Sri Durga Nellore Mess          Yes         No  3.4 /5             356
# 24953     Food Box Restaurant           No         No     NaN               0
# 41137         Ginger & Garlic          Yes         No  3.6 /5              92
# 43849          The Biere Club          Yes        Yes  4.3 /5            3496
#
#                rest_type                             cuisines Cost_for_two  \
# 37911      Casual Dining                              Chinese        1,000
# 26120               Mess        Andhra, South Indian, Biryani          350
# 24953        Quick Bites                            Fast Food          400
# 41137        Quick Bites  South Indian, North Indian, Chinese          350
# 43849  Pub, Microbrewery        Continental, BBQ, Finger Food        1,700
#
#          Service_Category          City
# 37911            Delivery  Lavelle Road
# 26120            Dine-out  Kammanahalli
# 24953            Dine-out  Kalyan Nagar
# 41137            Delivery  Marathahalli
# 43849  Drinks & nightlife       MG Road

# %% [markdown]
# # Split Rating Column

# %%
df['Rating_out_of_5']=df['Rating'].str.extract(r'(\d+.\d+|\d+)',expand=True)
df['Rating_out_of_5']=pd.to_numeric(df['Rating_out_of_5'],errors='coerce')

# %%
df.drop(columns=['Rating'],inplace=True)

# %%
df.sample(5)
# Out:
#                               Name online_order book_table  Customer_rated  \
# 42044                         Jade          Yes        Yes             692
# 13460                          KFC          Yes         No             682
# 41101              New Royal Treat          Yes         No               0
# 50267  Khan Saheb Grills and Rolls          Yes         No             305
# 7558                     Tasty Box          Yes         No               0
#
#            rest_type                            cuisines Cost_for_two  \
# 42044  Casual Dining             Chinese, Seafood, Momos          750
# 13460    Quick Bites                   Burger, Fast Food          450
# 41101    Quick Bites               North Indian, Chinese          350
# 50267    Quick Bites                    Fast Food, Rolls          400
# 7558        Delivery  Arabian, Mughlai, Chinese, Biryani          300
#
#       Service_Category             City  Rating_out_of_5
# 42044         Dine-out     Marathahalli              3.7
# 13460         Delivery  Electronic City              3.9
# 41101         Delivery     Marathahalli              NaN
# 50267         Delivery       Whitefield              3.8
# 7558          Delivery      Brookefield              NaN

# %% [markdown]
# # Clean rest_type column

# %%
df['rest_type']=df['rest_type'].str.replace('Cafee','Cafe')

# %%
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Delivery', na=False), 'rest_type'] = 'Quick Bites'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Dine-out', na=False), 'rest_type'] = 'Casual Dining'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Cafes', na=False), 'rest_type'] = 'Cafe'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Desserts', na=False), 'rest_type'] = 'Dessert Parlor'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Drinks', na=False), 'rest_type'] = 'Pub,Bar'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Buffet', na=False), 'rest_type'] = 'Buffet'
df.loc[df['rest_type'].isna() & df['Service_Category'].str.contains('Pubs and bars', na=False), 'rest_type'] = 'Pub,Bar'

# %%
df.sample(5)
# Out:
#                                                    Name online_order  \
# 47988  Bengaluru Baking Company - JW Marriott Bengaluru           No
# 49802                                       Mane Ruchii           No
# 18520                                        Cake Genie           No
# 10638                            Veruthe Oru Thattukada          Yes
# 25112                             New Udupi Park Deluxe           No
#
#       book_table  Customer_rated       rest_type  \
# 47988         No             526    Bakery, Cafe
# 49802         No               0     Quick Bites
# 18520         No             149  Dessert Parlor
# 10638         No              27     Quick Bites
# 25112         No              77     Quick Bites
#
#                                              cuisines Cost_for_two  \
# 47988  Salad, Bakery, Cafe, Sandwich, Italian, Burger        1,400
# 49802                    South Indian, Chinese, Kebab          400
# 18520                             Desserts, Fast Food          300
# 10638                            Kerala, South Indian          400
# 25112             South Indian, North Indian, Chinese          400
#
#       Service_Category            City  Rating_out_of_5
# 47988         Desserts  Residency Road              4.3
# 49802         Dine-out   Sarjapur Road              NaN
# 18520         Desserts     Indiranagar              3.9
# 10638         Dine-out             BTM              3.7
# 25112         Dine-out    Kalyan Nagar              3.6

# %% [markdown]
# # Fill missing values for Cost_for_two column

# %%
df['Cost_for_two']=df['Cost_for_two'].str.replace(',','')
df['Cost_for_two']=pd.to_numeric(df['Cost_for_two'],errors='coerce')

# %%
df['Cost_for_two'] = df.groupby(['City', 'rest_type'])['Cost_for_two'].transform(lambda x: x.fillna(x.median()))
df['Cost_for_two'] = df.groupby(['City', 'Service_Category'])['Cost_for_two'].transform(lambda x: x.fillna(x.median()))
# Out:
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# d:\Shourya_Personal_Files\Python_Directories\Python_Projects\Zoamto_Dataset\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
